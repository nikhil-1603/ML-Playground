# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import r2_score

# %%
df = pd.read_csv('placement.csv')
df.head(10)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57
# 5  7.89     2.99
# 6  6.73     2.60
# 7  6.75     2.48
# 8  6.09     2.31
# 9  8.31     3.51

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:, 0:1]
y = df.iloc[:, -1]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[2].values.reshape(1,1))
# Out:
# C:\Users\Nikhil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([2.38964753])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
slope = lr.coef_

# %%
lr.coef_
# Out:
# array([0.55574241])

# %%
c = lr.intercept_

# %%
lr.intercept_
# Out:
# np.float64(-0.8781178361812025)

# %%
# y = mx + c
slope*10 + c
# Out:
# array([4.67930626])

# %%
accuracy = lr.score(X_test,y_test)
print(f'Accuracy of the model is {accuracy*100:.2f}%')
# Out:
# Accuracy of the model is 77.36%

# %%
r2_score = r2_score(y_test, lr.predict(X_test))
print(f'R^2 score of the model is {r2_score:.2f}')
# Out:
# R^2 score of the model is 0.77
