# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('placement.csv')

# %%
plt.scatter(df['cgpa'],df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
X
# Out:
#      cgpa
# 0    6.89
# 1    5.12
# 2    7.82
# 3    7.42
# 4    6.94
# ..    ...
# 195  6.93
# 196  5.89
# 197  7.21
# 198  7.63
# 199  6.22
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=2)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# C:\Users\Nikhil\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.90615968])

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('CGPA')
plt.ylabel('Package(in lpa)')
# Out:
# Text(0, 0.5, 'Package(in lpa)')

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,r2_score

# %%
y_pred = lr.predict(X_test)

# %%
y_test.values
# Out:
# array([4.1 , 3.49, 2.08, 2.33, 1.94, 1.48, 1.86, 3.09, 4.21, 2.87, 3.65,
#        4.  , 2.89, 2.6 , 2.99, 3.25, 1.86, 3.67, 2.37, 3.42, 2.48, 3.65,
#        2.6 , 2.83, 4.08, 2.56, 3.58, 3.81, 4.09, 2.01, 3.63, 2.92, 3.51,
#        1.94, 2.21, 3.34, 3.34, 3.23, 2.01, 2.61, 3.13, 3.91, 2.25, 2.3 ,
#        4.06, 3.18, 2.7 , 2.49, 3.15, 2.99])

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 0.2925721381522003

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 0.12137452429115214

# %%
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# RMSE 0.34838846750596114

# %%
print("R2",r2_score(y_test,y_pred))
r2 = r2_score(y_test,y_pred)
# Out:
# R2 0.7626756914759928

# %%
X_test.shape
# Out:
# (50, 1)

# %%
# Adjusted R-squared score
1 - ((1-r2))*(50-1)/(50-2-1)
# Out:
# 0.7525767847302903

# %%
# Adding extra column to the data frame
new_df1 = df.copy()
new_df1['random_col'] = np.random.random(200)
new_df1 = new_df1[['cgpa','random_col','package']] 
new_df1.head()
# Out:
#    cgpa  random_col  package
# 0  6.89    0.254616     3.26
# 1  5.12    0.405600     1.98
# 2  7.82    0.203680     3.25
# 3  7.42    0.748571     3.67
# 4  6.94    0.842158     3.57

# %%
plt.scatter(new_df1['random_col'],new_df1['package'])
plt.xlabel('random_col')
plt.ylabel('packages( in LPA )')
# Out:
# Text(0, 0.5, 'packages( in LPA )')
